# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\hp\NLP_PROJECT\english_swahili_sentence_pairs.csv")

# %%
df
# Out:
#                                          English sentence  \
# 0                                                    I am
# 1                                                       U
# 2                                                     him
# 3                                                     her
# 4                                                     you
# ...                                                   ...
# 210466  A significant number of corporate companies wi...
# 210467  They held their annual seminar to educate athl...
# 210468  Uganda will be sending a capable group to the ...
# 210469  The coach has confidence that his team will wi...
# 210470  The vendors will be providing various services...
#
#                                       Swahili Translation
# 0                                                 mimi ni
# 1                                                    wewe
# 2                                                    yeye
# 3                                                    yeye
# 4                                                    wewe
# ...                                                   ...
# 210466  Idadi kubwa ya kampuni za ushirika zitashindan...
# 210467  Walifanya semina yao ya kila mwaka kuelimisha ...
# 210468  Uganda itakuwa ikituma kikundi chenye uwezo kw...
# 210469  Kocha anajiamini kuwa timu yake itashinda mchezo.
# 210470  Wauzaji watakuwa wakitoa huduma mbali mbali wa...
#
# [210471 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210471 entries, 0 to 210470
# Data columns (total 2 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   English sentence     210470 non-null  object
#  1   Swahili Translation  210470 non-null  object
# dtypes: object(2)
# memory usage: 3.2+ MB

# %%
#  missing values
df_cleaned = df.dropna()

#  Remove duplicate sentence pairs
df_cleaned = df_cleaned.drop_duplicates()

# %%
# Strip extra spaces from both columns
df_cleaned["English sentence"] = df_cleaned["English sentence"].str.strip()
df_cleaned["Swahili Translation"] = df_cleaned["Swahili Translation"].str.strip()

# %%
df_cleaned
# Out:
#                                          English sentence  \
# 0                                                    I am
# 1                                                       U
# 2                                                     him
# 3                                                     her
# 4                                                     you
# ...                                                   ...
# 210109  The national army safeguards the country's bor...
# 210121  I participated in last year's motor rally cham...
# 210128  This court mainly deals with crimes committed ...
# 210164   The company terminated their contract yesterday.
# 210169  The ministry of health has posted five health ...
#
#                                       Swahili Translation
# 0                                                 mimi ni
# 1                                                    wewe
# 2                                                    yeye
# 3                                                    yeye
# 4                                                    wewe
# ...                                                   ...
# 210109  Jeshi la Kitaifa linalinda mpaka wa nchi hiyo ...
# 210121  Nilishiriki katika Mashindano ya Rally ya Moto...
# 210128  Korti hii inashughulikia uhalifu uliofanywa na...
# 210164          Kampuni hiyo ilisitisha mkataba wao jana.
# 210169  Wizara ya Afya imeweka wafanyikazi watano wa a...
#
# [203346 rows x 2 columns]

# %%
#  Remove sentences that are too short (less than 2 characters)
df_cleaned = df_cleaned[df_cleaned["English sentence"].str.len() > 1]
df_cleaned = df_cleaned[df_cleaned["Swahili Translation"].str.len() > 1]

# %%
#  Convert to lowercase
df_cleaned["English sentence"] = df_cleaned["English sentence"].str.lower()
df_cleaned["Swahili Translation"] = df_cleaned["Swahili Translation"].str.lower()

# %%
df_cleaned.info(), df_cleaned.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 203326 entries, 0 to 210169
# Data columns (total 2 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   English sentence     203326 non-null  object
#  1   Swahili Translation  203326 non-null  object
# dtypes: object(2)
# memory usage: 4.7+ MB
# (None,
#    English sentence Swahili Translation
#  0             i am             mimi ni
#  2              him                yeye
#  3              her                yeye
#  4              you                wewe
#  5               we                sisi)

# %%
import re

# Function to clean text by removing numbers and unwanted characters
def clean_text(text):
    text = re.sub(r"[^a-zA-Z.,?!'’ ]", "", text)  # Keep letters, spaces, and punctuation
    text = re.sub(r"\s+", " ", text).strip()  # Remove extra spaces
    return text

# Apply the function to both columns
df_cleaned["English sentence"] = df_cleaned["English sentence"].apply(clean_text)
df_cleaned["Swahili Translation"] = df_cleaned["Swahili Translation"].apply(clean_text)

# Show sample cleaned data
df_cleaned.head()
# Out:
#   English sentence Swahili Translation
# 0             i am             mimi ni
# 2              him                yeye
# 3              her                yeye
# 4              you                wewe
# 5               we                sisi

# %%
df_cleaned.tail()
# Out:
#                                          English sentence  \
# 210109  the national army safeguards the country's bor...
# 210121  i participated in last year's motor rally cham...
# 210128  this court mainly deals with crimes committed ...
# 210164   the company terminated their contract yesterday.
# 210169  the ministry of health has posted five health ...
#
#                                       Swahili Translation
# 210109  jeshi la kitaifa linalinda mpaka wa nchi hiyo ...
# 210121  nilishiriki katika mashindano ya rally ya moto...
# 210128  korti hii inashughulikia uhalifu uliofanywa na...
# 210164          kampuni hiyo ilisitisha mkataba wao jana.
# 210169  wizara ya afya imeweka wafanyikazi watano wa a...

# %%
# Function to format text properly
def format_sentence(text):
    if len(text) == 0:
        return text  # Skip empty strings
    text = text.capitalize()  # Ensure first letter is uppercase
    if text[-1] not in ".?!":  # Ensure proper sentence ending
        text += "."  
    return text

# Apply formatting to both columns
df_cleaned["English sentence"] = df_cleaned["English sentence"].apply(format_sentence)
df_cleaned["Swahili Translation"] = df_cleaned["Swahili Translation"].apply(format_sentence)

# Show formatted sentences
df_cleaned.tail()
# Out:
#                                          English sentence  \
# 210109  The national army safeguards the country's bor...
# 210121  I participated in last year's motor rally cham...
# 210128  This court mainly deals with crimes committed ...
# 210164   The company terminated their contract yesterday.
# 210169  The ministry of health has posted five health ...
#
#                                       Swahili Translation
# 210109  Jeshi la kitaifa linalinda mpaka wa nchi hiyo ...
# 210121  Nilishiriki katika mashindano ya rally ya moto...
# 210128  Korti hii inashughulikia uhalifu uliofanywa na...
# 210164          Kampuni hiyo ilisitisha mkataba wao jana.
# 210169  Wizara ya afya imeweka wafanyikazi watano wa a...

# %% [markdown]
# **Checking wordlength imbalance**

# %%
# Compute word count for each sentence
df_cleaned["english_length"] = df_cleaned["English sentence"].apply(lambda x: len(x.split()))
df_cleaned["swahili_length"] = df_cleaned["Swahili Translation"].apply(lambda x: len(x.split()))

# Compute length ratio (English words / Swahili words)
df_cleaned["length_ratio"] = df_cleaned["english_length"] / df_cleaned["swahili_length"]

# Remove extreme imbalances (e.g., ratio > 3 or < 0.3)
df_cleaned = df_cleaned[(df_cleaned["length_ratio"] < 3) & (df_cleaned["length_ratio"] > 0.3)]

# %%
df_cleaned
# Out:
#                                          English sentence  \
# 0                                                   I am.
# 2                                                    Him.
# 3                                                    Her.
# 4                                                    You.
# 5                                                     We.
# ...                                                   ...
# 210109  The national army safeguards the country's bor...
# 210121  I participated in last year's motor rally cham...
# 210128  This court mainly deals with crimes committed ...
# 210164   The company terminated their contract yesterday.
# 210169  The ministry of health has posted five health ...
#
#                                       Swahili Translation  english_length  \
# 0                                                Mimi ni.               2
# 2                                                   Yeye.               1
# 3                                                   Yeye.               1
# 4                                                   Wewe.               1
# 5                                                   Sisi.               1
# ...                                                   ...             ...
# 210109  Jeshi la kitaifa linalinda mpaka wa nchi hiyo ...              11
# 210121  Nilishiriki katika mashindano ya rally ya moto...               8
# 210128  Korti hii inashughulikia uhalifu uliofanywa na...              10
# 210164          Kampuni hiyo ilisitisha mkataba wao jana.               6
# 210169  Wizara ya afya imeweka wafanyikazi watano wa a...              13
#
#         swahili_length  length_ratio
# 0                    2      1.000000
# 2                    1      1.000000
# 3                    1      1.000000
# 4                    1      1.000000
# 5                    1      1.000000
# ...                ...           ...
# 210109              14      0.785714
# 210121              11      0.727273
# 210128               9      1.111111
# 210164               6      1.000000
# 210169              13      1.000000
#
# [198959 rows x 5 columns]

# %%
# Drop helper columns
df_cleaned = df_cleaned.drop(columns=["english_length", "swahili_length", "length_ratio"])

# Show cleaned data
df_cleaned
# Out:
#                                          English sentence  \
# 0                                                   I am.
# 2                                                    Him.
# 3                                                    Her.
# 4                                                    You.
# 5                                                     We.
# ...                                                   ...
# 210109  The national army safeguards the country's bor...
# 210121  I participated in last year's motor rally cham...
# 210128  This court mainly deals with crimes committed ...
# 210164   The company terminated their contract yesterday.
# 210169  The ministry of health has posted five health ...
#
#                                       Swahili Translation
# 0                                                Mimi ni.
# 2                                                   Yeye.
# 3                                                   Yeye.
# 4                                                   Wewe.
# 5                                                   Sisi.
# ...                                                   ...
# 210109  Jeshi la kitaifa linalinda mpaka wa nchi hiyo ...
# 210121  Nilishiriki katika mashindano ya rally ya moto...
# 210128  Korti hii inashughulikia uhalifu uliofanywa na...
# 210164          Kampuni hiyo ilisitisha mkataba wao jana.
# 210169  Wizara ya afya imeweka wafanyikazi watano wa a...
#
# [198959 rows x 2 columns]

# %%
# Check for empty sentences after cleaning
df_cleaned = df_cleaned[(df_cleaned["English sentence"].str.len() > 1) & (df_cleaned["Swahili Translation"].str.len() > 1)]

# %%
df_cleaned.to_csv('english_swahili_sentence_pairs_cleaned.csv',index=False)

# %%
df=pd.read_csv(r"C:\Users\hp\NLP_PROJECT\english_swahili_sentence_pairs_cleaned.csv")

# %%
df
# Out:
#                                          English sentence  \
# 0                                                   I am.
# 1                                                    Him.
# 2                                                    Her.
# 3                                                    You.
# 4                                                     We.
# ...                                                   ...
# 198953  The national army safeguards the country's bor...
# 198954  I participated in last year's motor rally cham...
# 198955  This court mainly deals with crimes committed ...
# 198956   The company terminated their contract yesterday.
# 198957  The ministry of health has posted five health ...
#
#                                       Swahili Translation
# 0                                                Mimi ni.
# 1                                                   Yeye.
# 2                                                   Yeye.
# 3                                                   Wewe.
# 4                                                   Sisi.
# ...                                                   ...
# 198953  Jeshi la kitaifa linalinda mpaka wa nchi hiyo ...
# 198954  Nilishiriki katika mashindano ya rally ya moto...
# 198955  Korti hii inashughulikia uhalifu uliofanywa na...
# 198956          Kampuni hiyo ilisitisha mkataba wao jana.
# 198957  Wizara ya afya imeweka wafanyikazi watano wa a...
#
# [198958 rows x 2 columns]
