# %%
import numpy as np
import pandas as pd

# %%
pip install datasets
# Out:
# ...
#    ---------------------------------------- 0.0/484.9 kB ? eta -:--:--
#     --------------------------------------- 10.2/484.9 kB ? eta -:--:--
#    -- ------------------------------------ 30.7/484.9 kB 435.7 kB/s eta 0:00:02
#    -- ------------------------------------ 30.7/484.9 kB 435.7 kB/s eta 0:00:02
#    -- ------------------------------------ 30.7/484.9 kB 435.7 kB/s eta 0:00:02
#    --- ----------------------------------- 41.0/484.9 kB 163.4 kB/s eta 0:00:03
#    ---- ---------------------------------- 61.4/484.9 kB 233.8 kB/s eta 0:00:02
#    ------- ------------------------------- 92.2/484.9 kB 290.5 kB/s eta 0:00:02
#    ------- ------------------------------- 92.2/484.9 kB 290.5 kB/s eta 0:00:02
#    ------- ------------------------------- 92.2/484.9 kB 290.5 kB/s eta 0:00:02
#    ------- ------------------------------- 92.2/484.9 kB 290.5 kB/s eta 0:00:02
#    ----------- -------------------------- 143.4/484.9 kB 274.5 kB/s eta 0:00:02
# ...

# %%
pip install --upgrade pyarrow datasets
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from datasets import load_dataset

# Load the dataset
dataset = load_dataset("Rogendo/English-Swahili-Sentence-Pairs", split="train")
# Out:
# README.md:   0%|          | 0.00/173 [00:00<?, ?B/s]
# C:\Users\hp\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:142: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\hp\.cache\huggingface\hub\datasets--Rogendo--English-Swahili-Sentence-Pairs. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
# Convert to a Pandas DataFrame (optional)
import pandas as pd
df = pd.DataFrame(dataset)

# %%
df
# Out:
#                                          English sentence  \
# 0                                                    I am
# 1                                                       U
# 2                                                     him
# 3                                                     her
# 4                                                     you
# ...                                                   ...
# 210466  A significant number of corporate companies wi...
# 210467  They held their annual seminar to educate athl...
# 210468  Uganda will be sending a capable group to the ...
# 210469  The coach has confidence that his team will wi...
# 210470  The vendors will be providing various services...
#
#                                       Swahili Translation
# 0                                                 mimi ni
# 1                                                    wewe
# 2                                                    yeye
# ...

# %%
# Save as CSV
df.to_csv("english_swahili_sentence_pairs.csv", index=False)

print("Dataset downloaded and saved as CSV!")
# Out:
# Dataset downloaded and saved as CSV!

# %%
df=pd.read_csv(r"C:\Users\hp\NLP_PROJECT\english_swahili_sentence_pairs.csv")

# %%
df.head(50)
# Out:
#                                      English sentence  \
# 0                                                I am
# 1                                                   U
# 2                                                 him
# 3                                                 her
# 4                                                 you
# 5                                                  we
# 6                                                them
# 7                                               there
# 8                                             it's me
# 9                                                   I
# 10                                                  i
# 11                                      Are you sure?
# 12                                        I love you.
# 13  This is my friend Rachel. We went to high scho...
# 14                                 I have a headache.
# 15               Where there's a will, there's a way.
# ...
